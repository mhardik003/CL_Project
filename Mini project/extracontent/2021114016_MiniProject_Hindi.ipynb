# %% [markdown]
# # CRAWLING (Web Scraping)

# %%
# !pip install inltk
import re
import numpy as np
from matplotlib import pyplot as plt
from pprint import pprint
from collections import Counter
from bs4 import BeautifulSoup
import requests
# !pip3 install beautifulsoup4
# !pip3 install requests
# !pip3 install wordcloud
from wordcloud import WordCloud, STOPWORDS
# !pip install stanza
import stanza
stanza.download('hi')
nlp = stanza.Pipeline('hi') 
# !pip3 install nltk
import nltk
nltk.download('indian')
nltk.download('punkt')

import sys
sys.setrecursionlimit(15000)

from nltk.tag import tnt
from nltk.corpus import indian

# !pip install indic-transliteration
from indic_transliteration import sanscript
from indic_transliteration.sanscript import transliterate

stanza.download('hi')
hi_nlp = stanza.Pipeline('hi')

from inltk.inltk import tokenize
from inltk.inltk import setup
setup('hi')
# Out:
# Requirement already satisfied: inltk in /home/hardk/anaconda3/lib/python3.9/site-packages (0.9)
# Requirement already satisfied: nvidia-ml-py3 in /home/hardk/anaconda3/lib/python3.9/site-packages (from inltk) (7.352.0)
# Requirement already satisfied: sentencepiece in /home/hardk/anaconda3/lib/python3.9/site-packages (from inltk) (0.1.96)
# Requirement already satisfied: bottleneck in /home/hardk/anaconda3/lib/python3.9/site-packages (from inltk) (1.3.4)
# Requirement already satisfied: pyyaml in /home/hardk/anaconda3/lib/python3.9/site-packages (from inltk) (6.0)
# Requirement already satisfied: packaging in /home/hardk/anaconda3/lib/python3.9/site-packages (from inltk) (21.3)
# Requirement already satisfied: fastprogress>=0.1.19 in /home/hardk/anaconda3/lib/python3.9/site-packages (from inltk) (1.0.2)
# Requirement already satisfied: fastai==1.0.57 in /home/hardk/anaconda3/lib/python3.9/site-packages (from inltk) (1.0.57)
# Requirement already satisfied: matplotlib in /home/hardk/anaconda3/lib/python3.9/site-packages (from inltk) (3.5.1)
# Requirement already satisfied: pandas in /home/hardk/anaconda3/lib/python3.9/site-packages (from inltk) (1.4.2)
# Requirement already satisfied: aiohttp>=3.5.4 in /home/hardk/anaconda3/lib/python3.9/site-packages (from inltk) (3.8.1)
# Requirement already satisfied: requests in /home/hardk/anaconda3/lib/python3.9/site-packages (from inltk) (2.27.1)
# Requirement already satisfied: numpy>=1.15 in /home/hardk/anaconda3/lib/python3.9/site-packages (from inltk) (1.21.5)
# Requirement already satisfied: spacy>=2.0.18 in /home/hardk/anaconda3/lib/python3.9/site-packages (from inltk) (3.3.0)
# Requirement already satisfied: beautifulsoup4 in /home/hardk/anaconda3/lib/python3.9/site-packages (from inltk) (4.11.1)
# Requirement already satisfied: async-timeout>=3.0.1 in /home/hardk/anaconda3/lib/python3.9/site-packages (from inltk) (4.0.1)
# Requirement already satisfied: Pillow in /home/hardk/anaconda3/lib/python3.9/site-packages (from inltk) (9.0.1)
# Requirement already satisfied: scipy in /home/hardk/anaconda3/lib/python3.9/site-packages (from inltk) (1.7.3)
# Requirement already satisfied: typing in /home/hardk/anaconda3/lib/python3.9/site-packages (from inltk) (3.7.4.3)
# Requirement already satisfied: numexpr in /home/hardk/anaconda3/lib/python3.9/site-packages (from inltk) (2.8.1)
# Requirement already satisfied: torchvision in /home/hardk/anaconda3/lib/python3.9/site-packages (from fastai==1.0.57->inltk) (0.12.0)
# Requirement already satisfied: torch>=1.0.0 in /home/hardk/anaconda3/lib/python3.9/site-packages (from fastai==1.0.57->inltk) (1.11.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/hardk/anaconda3/lib/python3.9/site-packages (from aiohttp>=3.5.4->inltk) (5.2.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/hardk/anaconda3/lib/python3.9/site-packages (from aiohttp>=3.5.4->inltk) (1.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/hardk/anaconda3/lib/python3.9/site-packages (from aiohttp>=3.5.4->inltk) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/hardk/anaconda3/lib/python3.9/site-packages (from aiohttp>=3.5.4->inltk) (21.4.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /home/hardk/anaconda3/lib/python3.9/site-packages (from aiohttp>=3.5.4->inltk) (2.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/hardk/anaconda3/lib/python3.9/site-packages (from aiohttp>=3.5.4->inltk) (1.6.3)
# Requirement already satisfied: typing-extensions>=3.6.5 in /home/hardk/anaconda3/lib/python3.9/site-packages (from async-timeout>=3.0.1->inltk) (4.1.1)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/hardk/anaconda3/lib/python3.9/site-packages (from spacy>=2.0.18->inltk) (1.0.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/hardk/anaconda3/lib/python3.9/site-packages (from spacy>=2.0.18->inltk) (2.0.6)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /home/hardk/anaconda3/lib/python3.9/site-packages (from spacy>=2.0.18->inltk) (0.9.1)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /home/hardk/anaconda3/lib/python3.9/site-packages (from spacy>=2.0.18->inltk) (0.4.1)
# Requirement already satisfied: pathy>=0.3.5 in /home/hardk/anaconda3/lib/python3.9/site-packages (from spacy>=2.0.18->inltk) (0.6.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in /home/hardk/anaconda3/lib/python3.9/site-packages (from spacy>=2.0.18->inltk) (3.0.9)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /home/hardk/anaconda3/lib/python3.9/site-packages (from spacy>=2.0.18->inltk) (0.7.7)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/hardk/anaconda3/lib/python3.9/site-packages (from spacy>=2.0.18->inltk) (2.0.7)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/hardk/anaconda3/lib/python3.9/site-packages (from spacy>=2.0.18->inltk) (4.64.0)
# Requirement already satisfied: jinja2 in /home/hardk/anaconda3/lib/python3.9/site-packages (from spacy>=2.0.18->inltk) (2.11.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/hardk/anaconda3/lib/python3.9/site-packages (from spacy>=2.0.18->inltk) (3.0.6)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/hardk/anaconda3/lib/python3.9/site-packages (from spacy>=2.0.18->inltk) (1.0.7)
# Requirement already satisfied: thinc<8.1.0,>=8.0.14 in /home/hardk/anaconda3/lib/python3.9/site-packages (from spacy>=2.0.18->inltk) (8.0.15)
# Requirement already satisfied: setuptools in /home/hardk/anaconda3/lib/python3.9/site-packages (from spacy>=2.0.18->inltk) (61.2.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /home/hardk/anaconda3/lib/python3.9/site-packages (from spacy>=2.0.18->inltk) (1.8.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/hardk/anaconda3/lib/python3.9/site-packages (from spacy>=2.0.18->inltk) (3.3.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/hardk/anaconda3/lib/python3.9/site-packages (from spacy>=2.0.18->inltk) (2.4.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/hardk/anaconda3/lib/python3.9/site-packages (from packaging->inltk) (3.0.4)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /home/hardk/anaconda3/lib/python3.9/site-packages (from pathy>=0.3.5->spacy>=2.0.18->inltk) (5.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/hardk/anaconda3/lib/python3.9/site-packages (from requests->inltk) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/hardk/anaconda3/lib/python3.9/site-packages (from requests->inltk) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/hardk/anaconda3/lib/python3.9/site-packages (from requests->inltk) (1.26.9)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/hardk/anaconda3/lib/python3.9/site-packages (from typer<0.5.0,>=0.3.0->spacy>=2.0.18->inltk) (8.0.4)
# Requirement already satisfied: soupsieve>1.2 in /home/hardk/anaconda3/lib/python3.9/site-packages (from beautifulsoup4->inltk) (2.3.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/hardk/anaconda3/lib/python3.9/site-packages (from jinja2->spacy>=2.0.18->inltk) (2.0.1)
# Requirement already satisfied: cycler>=0.10 in /home/hardk/anaconda3/lib/python3.9/site-packages (from matplotlib->inltk) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/hardk/anaconda3/lib/python3.9/site-packages (from matplotlib->inltk) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/hardk/anaconda3/lib/python3.9/site-packages (from matplotlib->inltk) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /home/hardk/anaconda3/lib/python3.9/site-packages (from matplotlib->inltk) (4.25.0)
# Requirement already satisfied: six>=1.5 in /home/hardk/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->inltk) (1.16.0)
# Requirement already satisfied: pytz>=2020.1 in /home/hardk/anaconda3/lib/python3.9/site-packages (from pandas->inltk) (2021.3)
# Requirement already satisfied: beautifulsoup4 in /home/hardk/anaconda3/lib/python3.9/site-packages (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in /home/hardk/anaconda3/lib/python3.9/site-packages (from beautifulsoup4) (2.3.1)
# Requirement already satisfied: requests in /home/hardk/anaconda3/lib/python3.9/site-packages (2.27.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/hardk/anaconda3/lib/python3.9/site-packages (from requests) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/hardk/anaconda3/lib/python3.9/site-packages (from requests) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/hardk/anaconda3/lib/python3.9/site-packages (from requests) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /home/hardk/anaconda3/lib/python3.9/site-packages (from requests) (3.3)
# Requirement already satisfied: wordcloud in /home/hardk/anaconda3/lib/python3.9/site-packages (1.8.1)
# Requirement already satisfied: matplotlib in /home/hardk/anaconda3/lib/python3.9/site-packages (from wordcloud) (3.5.1)
# Requirement already satisfied: pillow in /home/hardk/anaconda3/lib/python3.9/site-packages (from wordcloud) (9.0.1)
# Requirement already satisfied: numpy>=1.6.1 in /home/hardk/anaconda3/lib/python3.9/site-packages (from wordcloud) (1.21.5)
# Requirement already satisfied: cycler>=0.10 in /home/hardk/anaconda3/lib/python3.9/site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/hardk/anaconda3/lib/python3.9/site-packages (from matplotlib->wordcloud) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in /home/hardk/anaconda3/lib/python3.9/site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/hardk/anaconda3/lib/python3.9/site-packages (from matplotlib->wordcloud) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in /home/hardk/anaconda3/lib/python3.9/site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in /home/hardk/anaconda3/lib/python3.9/site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: six>=1.5 in /home/hardk/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Requirement already satisfied: stanza in /home/hardk/anaconda3/lib/python3.9/site-packages (1.4.0)
# Requirement already satisfied: protobuf in /home/hardk/anaconda3/lib/python3.9/site-packages (from stanza) (3.19.1)
# Requirement already satisfied: six in /home/hardk/anaconda3/lib/python3.9/site-packages (from stanza) (1.16.0)
# Requirement already satisfied: transformers in /home/hardk/anaconda3/lib/python3.9/site-packages (from stanza) (4.19.0)
# Requirement already satisfied: numpy in /home/hardk/anaconda3/lib/python3.9/site-packages (from stanza) (1.21.5)
# Requirement already satisfied: emoji in /home/hardk/anaconda3/lib/python3.9/site-packages (from stanza) (1.7.0)
# Requirement already satisfied: torch>=1.3.0 in /home/hardk/anaconda3/lib/python3.9/site-packages (from stanza) (1.11.0)
# Requirement already satisfied: tqdm in /home/hardk/anaconda3/lib/python3.9/site-packages (from stanza) (4.64.0)
# Requirement already satisfied: requests in /home/hardk/anaconda3/lib/python3.9/site-packages (from stanza) (2.27.1)
# Requirement already satisfied: typing-extensions in /home/hardk/anaconda3/lib/python3.9/site-packages (from torch>=1.3.0->stanza) (4.1.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/hardk/anaconda3/lib/python3.9/site-packages (from requests->stanza) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/hardk/anaconda3/lib/python3.9/site-packages (from requests->stanza) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in /home/hardk/anaconda3/lib/python3.9/site-packages (from requests->stanza) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /home/hardk/anaconda3/lib/python3.9/site-packages (from requests->stanza) (3.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /home/hardk/anaconda3/lib/python3.9/site-packages (from transformers->stanza) (0.6.0)
# Requirement already satisfied: filelock in /home/hardk/anaconda3/lib/python3.9/site-packages (from transformers->stanza) (3.6.0)
# Requirement already satisfied: regex!=2019.12.17 in /home/hardk/anaconda3/lib/python3.9/site-packages (from transformers->stanza) (2022.3.15)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in /home/hardk/anaconda3/lib/python3.9/site-packages (from transformers->stanza) (0.12.1)
# Requirement already satisfied: pyyaml>=5.1 in /home/hardk/anaconda3/lib/python3.9/site-packages (from transformers->stanza) (6.0)
# Requirement already satisfied: packaging>=20.0 in /home/hardk/anaconda3/lib/python3.9/site-packages (from transformers->stanza) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/hardk/anaconda3/lib/python3.9/site-packages (from packaging>=20.0->transformers->stanza) (3.0.4)
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.4.0.json:   0%|   …
# 2022-05-13 01:11:29 INFO: Downloading default packages for language: hi (Hindi)...
# 2022-05-13 01:11:30 INFO: File exists: /home/hardk/stanza_resources/hi/default.zip
# 2022-05-13 01:11:31 INFO: Finished downloading models and saved to /home/hardk/stanza_resources.
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.4.0.json:   0%|   …
# 2022-05-13 01:11:32 INFO: Loading these models for language: hi (Hindi):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | hdtb    |
# | pos       | hdtb    |
# | lemma     | hdtb    |
# | depparse  | hdtb    |
# =======================
#
# 2022-05-13 01:11:32 INFO: Use device: cpu
# 2022-05-13 01:11:32 INFO: Loading: tokenize
# 2022-05-13 01:11:32 INFO: Loading: pos
# 2022-05-13 01:11:32 INFO: Loading: lemma
# 2022-05-13 01:11:32 INFO: Loading: depparse
# 2022-05-13 01:11:32 INFO: Done loading processors!
# Requirement already satisfied: nltk in /home/hardk/anaconda3/lib/python3.9/site-packages (3.7)
# Requirement already satisfied: joblib in /home/hardk/anaconda3/lib/python3.9/site-packages (from nltk) (1.1.0)
# Requirement already satisfied: tqdm in /home/hardk/anaconda3/lib/python3.9/site-packages (from nltk) (4.64.0)
# Requirement already satisfied: regex>=2021.8.3 in /home/hardk/anaconda3/lib/python3.9/site-packages (from nltk) (2022.3.15)
# Requirement already satisfied: click in /home/hardk/anaconda3/lib/python3.9/site-packages (from nltk) (8.0.4)
# [nltk_data] Downloading package indian to /home/hardk/nltk_data...
# [nltk_data]   Package indian is already up-to-date!
# [nltk_data] Downloading package punkt to /home/hardk/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Requirement already satisfied: indic-transliteration in /home/hardk/anaconda3/lib/python3.9/site-packages (2.3.26)
# Requirement already satisfied: backports.functools-lru-cache in /home/hardk/anaconda3/lib/python3.9/site-packages (from indic-transliteration) (1.6.4)
# Requirement already satisfied: roman in /home/hardk/anaconda3/lib/python3.9/site-packages (from indic-transliteration) (3.3)
# Requirement already satisfied: regex in /home/hardk/anaconda3/lib/python3.9/site-packages (from indic-transliteration) (2022.3.15)
# Requirement already satisfied: typer in /home/hardk/anaconda3/lib/python3.9/site-packages (from indic-transliteration) (0.4.1)
# Requirement already satisfied: toml in /home/hardk/anaconda3/lib/python3.9/site-packages (from indic-transliteration) (0.10.2)
# Requirement already satisfied: selenium in /home/hardk/anaconda3/lib/python3.9/site-packages (from indic-transliteration) (4.1.5)
# Requirement already satisfied: urllib3[secure,socks]~=1.26 in /home/hardk/anaconda3/lib/python3.9/site-packages (from selenium->indic-transliteration) (1.26.9)
# Requirement already satisfied: trio-websocket~=0.9 in /home/hardk/anaconda3/lib/python3.9/site-packages (from selenium->indic-transliteration) (0.9.2)
# Requirement already satisfied: trio~=0.17 in /home/hardk/anaconda3/lib/python3.9/site-packages (from selenium->indic-transliteration) (0.20.0)
# Requirement already satisfied: idna in /home/hardk/anaconda3/lib/python3.9/site-packages (from trio~=0.17->selenium->indic-transliteration) (3.3)
# Requirement already satisfied: async-generator>=1.9 in /home/hardk/anaconda3/lib/python3.9/site-packages (from trio~=0.17->selenium->indic-transliteration) (1.10)
# Requirement already satisfied: sniffio in /home/hardk/anaconda3/lib/python3.9/site-packages (from trio~=0.17->selenium->indic-transliteration) (1.2.0)
# Requirement already satisfied: attrs>=19.2.0 in /home/hardk/anaconda3/lib/python3.9/site-packages (from trio~=0.17->selenium->indic-transliteration) (21.4.0)
# Requirement already satisfied: sortedcontainers in /home/hardk/anaconda3/lib/python3.9/site-packages (from trio~=0.17->selenium->indic-transliteration) (2.4.0)
# Requirement already satisfied: outcome in /home/hardk/anaconda3/lib/python3.9/site-packages (from trio~=0.17->selenium->indic-transliteration) (1.1.0)
# Requirement already satisfied: wsproto>=0.14 in /home/hardk/anaconda3/lib/python3.9/site-packages (from trio-websocket~=0.9->selenium->indic-transliteration) (1.1.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in /home/hardk/anaconda3/lib/python3.9/site-packages (from urllib3[secure,socks]~=1.26->selenium->indic-transliteration) (1.7.1)
# Requirement already satisfied: cryptography>=1.3.4 in /home/hardk/anaconda3/lib/python3.9/site-packages (from urllib3[secure,socks]~=1.26->selenium->indic-transliteration) (3.4.8)
# Requirement already satisfied: pyOpenSSL>=0.14 in /home/hardk/anaconda3/lib/python3.9/site-packages (from urllib3[secure,socks]~=1.26->selenium->indic-transliteration) (21.0.0)
# Requirement already satisfied: certifi in /home/hardk/anaconda3/lib/python3.9/site-packages (from urllib3[secure,socks]~=1.26->selenium->indic-transliteration) (2021.10.8)
# Requirement already satisfied: cffi>=1.12 in /home/hardk/anaconda3/lib/python3.9/site-packages (from cryptography>=1.3.4->urllib3[secure,socks]~=1.26->selenium->indic-transliteration) (1.15.0)
# Requirement already satisfied: pycparser in /home/hardk/anaconda3/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=1.3.4->urllib3[secure,socks]~=1.26->selenium->indic-transliteration) (2.21)
# Requirement already satisfied: six>=1.5.2 in /home/hardk/anaconda3/lib/python3.9/site-packages (from pyOpenSSL>=0.14->urllib3[secure,socks]~=1.26->selenium->indic-transliteration) (1.16.0)
# Requirement already satisfied: h11<1,>=0.9.0 in /home/hardk/anaconda3/lib/python3.9/site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium->indic-transliteration) (0.13.0)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/hardk/anaconda3/lib/python3.9/site-packages (from typer->indic-transliteration) (8.0.4)
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.4.0.json:   0%|   …
# 2022-05-13 01:11:38 INFO: Downloading default packages for language: hi (Hindi)...
# 2022-05-13 01:11:39 INFO: File exists: /home/hardk/stanza_resources/hi/default.zip
# 2022-05-13 01:11:40 INFO: Finished downloading models and saved to /home/hardk/stanza_resources.
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.4.0.json:   0%|   …
# 2022-05-13 01:11:41 INFO: Loading these models for language: hi (Hindi):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | hdtb    |
# | pos       | hdtb    |
# | lemma     | hdtb    |
# | depparse  | hdtb    |
# =======================
#
# 2022-05-13 01:11:41 INFO: Use device: cpu
# 2022-05-13 01:11:41 INFO: Loading: tokenize
# 2022-05-13 01:11:41 INFO: Loading: pos
# 2022-05-13 01:11:41 INFO: Loading: lemma
# 2022-05-13 01:11:41 INFO: Loading: depparse
# 2022-05-13 01:11:41 INFO: Done loading processors!
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Input In [62], in <cell line: 37>()
#      35 from inltk.inltk import tokenize
#      36 from inltk.inltk import setup
# ---> 37 setup('hi')
#
# File ~/anaconda3/lib/python3.9/site-packages/inltk/inltk.py:33, in setup(language_code)
#      <a href='file:///home/hardk/anaconda3/lib/python3.9/site-packages/inltk/inltk.py?line=30'>31</a> loop = asyncio.get_event_loop()
#      <a href='file:///home/hardk/anaconda3/lib/python3.9/site-packages/inltk/inltk.py?line=31'>32</a> tasks = [asyncio.ensure_future(download(language_code))]
# ---> <a href='file:///home/hardk/anaconda3/lib/python3.9/site-packages/inltk/inltk.py?line=32'>33</a> learn = loop.run_until_complete(asyncio.gather(*tasks))[0]
#      <a href='file:///home/hardk/anaconda3/lib/python3.9/site-packages/inltk/inltk.py?line=33'>34</a> loop.close()
#
# File ~/anaconda3/lib/python3.9/asyncio/base_events.py:623, in BaseEventLoop.run_until_complete(self, future)
#     <a href='file:///home/hardk/anaconda3/lib/python3.9/asyncio/base_events.py?line=611'>612</a> """Run until the Future is done.
#     <a href='file:///home/hardk/anaconda3/lib/python3.9/asyncio/base_events.py?line=612'>613</a>
#     <a href='file:///home/hardk/anaconda3/lib/python3.9/asyncio/base_events.py?line=613'>614</a> If the argument is a coroutine, it is wrapped in a Task.
#    (...)
#     <a href='file:///home/hardk/anaconda3/lib/python3.9/asyncio/base_events.py?line=619'>620</a> Return the Future's result, or raise its exception.
#     <a href='file:///home/hardk/anaconda3/lib/python3.9/asyncio/base_events.py?line=620'>621</a> """
#     <a href='file:///home/hardk/anaconda3/lib/python3.9/asyncio/base_events.py?line=621'>622</a> self._check_closed()
# --> <a href='file:///home/hardk/anaconda3/lib/python3.9/asyncio/base_events.py?line=622'>623</a> self._check_running()
#     <a href='file:///home/hardk/anaconda3/lib/python3.9/asyncio/base_events.py?line=624'>625</a> new_task = not futures.isfuture(future)
#     <a href='file:///home/hardk/anaconda3/lib/python3.9/asyncio/base_events.py?line=625'>626</a> future = tasks.ensure_future(future, loop=self)
#
# File ~/anaconda3/lib/python3.9/asyncio/base_events.py:583, in BaseEventLoop._check_running(self)
#     <a href='file:///home/hardk/anaconda3/lib/python3.9/asyncio/base_events.py?line=580'>581</a> def _check_running(self):
#     <a href='file:///home/hardk/anaconda3/lib/python3.9/asyncio/base_events.py?line=581'>582</a>     if self.is_running():
# --> <a href='file:///home/hardk/anaconda3/lib/python3.9/asyncio/base_events.py?line=582'>583</a>         raise RuntimeError('This event loop is already running')
#     <a href='file:///home/hardk/anaconda3/lib/python3.9/asyncio/base_events.py?line=583'>584</a>     if events._get_running_loop() is not None:
#     <a href='file:///home/hardk/anaconda3/lib/python3.9/asyncio/base_events.py?line=584'>585</a>         raise RuntimeError(
#     <a href='file:///home/hardk/anaconda3/lib/python3.9/asyncio/base_events.py?line=585'>586</a>             'Cannot run the event loop while another loop is running')
#
# RuntimeError: This event loop is already running
# Done!

# %%
url = 'https://www.deepawali.co.in/nibandh-essay-hindi'
req = requests.get(url)
#print(req.content)
html_content = req.content
soup = BeautifulSoup(html_content, 'html.parser')
#pprint(soup.prettify())

# %%
def get_sentences(url, corpus, sentences, links):
    req = requests.get(url)
    html_content = req.content
    soup = BeautifulSoup(html_content, 'html.parser')
    links_corpus = soup.find_all('a')
    for i in links_corpus:
        link = i.get('href')
        if(link is not None):
            if(link.startswith('https://www.deepawali.co.in')):
                # print(link)
                links.append(link)
                req = requests.get(link)
                html_content = req.content
                soup = BeautifulSoup(html_content, 'html.parser')
                content_corpus = soup.find_all('p')
                # print(news_corpus[0].text)
                for j in content_corpus:
                    corpus = corpus+j.text
                    # for better tokenization
                    corpus = corpus.replace(".", "।")
                    # for better tokenization
                    corpus = corpus.replace("?", "।")
                    # for better tokenization
                    corpus = corpus.replace("!", "।")
                    sentences = corpus.split("।")
                    # print(sentences)
                    # print("Sentences length : ", len(sentences))
                    # print("URLS length : ", len(links))
                    if(len(sentences) > 10000):
                        return corpus
    #print("Calling the function again with the link : ", links[-1])
    corpus = get_sentences(links[-1], corpus, sentences, links)
    return corpus

# %%
corpus = ""
links = []
sentences = []
temp=[]
links.append(url)
corpus = get_sentences(url, corpus, sentences, links)

#print(len(sentences))

# %%
# for sentence in sentences:
#     print(sentence)

#print(corpus)

# %% [markdown]
# ### CLEANING THE CORPUS

# %%
corpus = re.sub("[0-9][A-Z]|[a-z]", "", corpus)
#print(corpus_text_hindi)

corpus=corpus.replace("|","")
corpus=corpus.replace(")","")
corpus=corpus.replace("(","")
sentences = corpus.split("।")
sentences = [sentence for sentence in sentences if sentence!=""]
sentences = [sentence for sentence in sentences if sentence!=" "]

# for sentence in sentences:
#     print(sentence)
clean_corpus = ' '.join(sentences)+' '

# %% [markdown]
# ### WORD TOKENIZATION

# %%
words =[]
for sentence in sentences:
    words.extend(sentence.split(" "))

words=[word for word in words if word]
#print(words)
word_count=Counter(words)
#print(words_counter.most_common(10))

word_count_dict={}
for word in words_without_stopwords: 
  word_count_dict.setdefault(transliterate(word, sanscript.DEVANAGARI,sanscript.ITRANS),0 )
  word_count_dict[transliterate(word, sanscript.DEVANAGARI,sanscript.ITRANS)]= word_count_dict[transliterate(word, sanscript.DEVANAGARI,sanscript.ITRANS)]+1
#print(word_count_dict)

word_count=Counter(word_count_dict)
#print(word_count)
fig = plt.figure(figsize=(10,5))
plt.xlabel("WORDS")
plt.ylabel("FREQUENCIES")
plt.title("TOP 10 WORDS AND THEIR FREQUENCIES")
plt.bar([x for x,y in word_count.most_common(10)], [y for x,y in word_count.most_common(10)], width=0.5)
plt.plot([x for x,y in word_count.most_common(10)], [y for x,y in word_count.most_common(10)])
plt.show()

# %% [markdown]
# ### POS TAGGING

# %%
from nltk.tag import tnt
from nltk.corpus import indian

words_string=' '.join(words)+' '


train_data = indian.tagged_sents('hindi.pos')
tnt_pos_tagger = tnt.TnT()
tnt_pos_tagger.train(train_data)

tagged_words_list=[]
for word in words:
    tagged_words_list.extend(tnt_pos_tagger.tag(nltk.word_tokenize(word)))
    #print(tagged_words)

#print(tagged_words_list)
tagged_words_counter= Counter([tagged_word[1] for tagged_word in tagged_words_list])
#print(tagged_words_counter)
fig = plt.figure(figsize=(10,5))
plt.xlabel("POS TAGS")
plt.ylabel("FREQUENCIES")
plt.title("TOP 10 POS TAGS AND THEIR FREQUENCIES")
plt.bar([x for x,y in tagged_words_counter.most_common(10)], [y for x,y in tagged_words_counter.most_common(10)], width=0.5)
plt.plot([x for x,y in tagged_words_counter.most_common(10)], [y for x,y in tagged_words_counter.most_common(10)])
plt.show()

# %% [markdown]
# ### STOP WORDS

# %%
HINDI_STOP_WORDS = ["के", "का", "एक", "में", "की", "है", "यह", "और", "से", "हैं", "को", "पर", "इस", "होता", "कि", "जो", "कर", "मे", "गया", "करने", "किया", "लिये", "अपने", "ने", "बनी", "नहीं", "तो", "ही", "या", "एवं", "दिया", "हो", "इसका", "था", "द्वारा", "हुआ", "तक", "साथ", "करना", "वाले", "बाद", "लिए", "आप", "कुछ", "सकते", "किसी", "ये", "इसके", "सबसे",
                    "इसमें", "थे", "दो", "होने", "वह", "वे", "करते", "बहुत", "कहा", "वर्ग", "कई", "करें", "होती", "अपनी", "उनके", "थी", "यदि", "हुई", "जा", "ना", "इसे", "कहते", "जब", "होते", 'कोई', "हुए", "व", "न", "अभी", "जैसे", "सभी", "करता", "उनकी", "तरह", "उस", "आदि", "कुल", "एस", "रहा", "इसकी", "सकता", "रहे", 'उनका', "इसी", "रखें", "अपना", "पे", "उसके", "भी", "तथा"]
words_without_stopwords = []
for word in words:
    if word not in HINDI_STOP_WORDS:
        words_without_stopwords.append(word)

word_count_dict={}
for word in words_without_stopwords: 
  word_count_dict.setdefault(transliterate(word, sanscript.DEVANAGARI,sanscript.ITRANS),0 )
  word_count_dict[transliterate(word, sanscript.DEVANAGARI,sanscript.ITRANS)]= word_count_dict[transliterate(word, sanscript.DEVANAGARI,sanscript.ITRANS)]+1

#print(word_count_dict)

counter_without_stopwords = Counter(words_without_stopwords)
counter_without_stopwords = Counter(word_count_dict)
fig = plt.figure(figsize=(10,5))
plt.xlabel("WORDS")
plt.ylabel("FREQUENCIES")
plt.title("TOP 10 WORDS AND THEIR FREQUENCIES EXCLUDING STOP WORDS")
plt.bar([x for x,y in counter_without_stopwords.most_common(10)], [y for x,y in counter_without_stopwords.most_common(10)], width=0.5)
plt.plot([x for x,y in counter_without_stopwords.most_common(10)], [y for x,y in counter_without_stopwords.most_common(10)])
plt.show()
# print(token_counter_hindi_without_stopwords)

# %% [markdown]
# ### LEMMATIZATION

# %%
hindi_doc = hi_nlp(clean_corpus) 

lemmatized_list=[]
for sentence in hindi_doc.sentences:
  for word in sentence.words:
    lemmatized_list.append(word.lemma)
lemmatized_counter=Counter(lemmatized_list)

lemmatized_list=[lemma for lemma in lemmatized_list if lemma!=',']

word_count_dict={}
for word in lemmatized_list: 
  word_count_dict.setdefault(transliterate(word, sanscript.DEVANAGARI,sanscript.ITRANS),0 )
  word_count_dict[transliterate(word, sanscript.DEVANAGARI,sanscript.ITRANS)]= word_count_dict[transliterate(word, sanscript.DEVANAGARI,sanscript.ITRANS)]+1

lemmatized_counter=Counter(word_count_dict)
#print(lemmatized_counter.most_common(10))
fig = plt.figure(figsize=(10,5))
plt.xlabel("WORDS")
plt.ylabel("FREQUENCIES")
plt.title("TOP 10 WORDS AND THEIR FREQUENCIES EXCLUDING STOP WORDS")
plt.bar([x for x,y in lemmatized_counter.most_common(10)], [y for x,y in lemmatized_counter.most_common(10)], width=0.5)
plt.plot([x for x,y in lemmatized_counter.most_common(10)], [y for x,y in lemmatized_counter.most_common(10)])
plt.show()

# %%
# word_count_dict={}
# for word in words_without_stopwords: 
#   word_count_dict.setdefault(transliterate(word, sanscript.DEVANAGARI,sanscript.ITRANS),0 )
#   word_count_dict[transliterate(word, sanscript.DEVANAGARI,sanscript.ITRANS)]= word_count_dict[transliterate(word, sanscript.DEVANAGARI,sanscript.ITRANS)]+1

# print(word_count_dict)

# %% [markdown]
# ### WORDCLOUD

# %%
wordcloud = WordCloud(width = 800, height = 800,max_words=120,
                background_color ='white',
                #stopwords = stopwords,
                min_font_size = 10).generate_from_frequencies(counter_without_stopwords)
 
# plot the WordCloud image                      
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 

 ## 120 words in the word cloud as these were comprising of approximately 75% of the data(after removing the stop words)
plt.show()
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
